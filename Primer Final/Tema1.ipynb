# %% [markdown]
# # Primer examen final
# ## Tema 1
# ### Angel David Veron Cuevas
# #### 5.660.159

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mruizolazar/DataScience-FPUNA/master/datos/autos_info.csv')
df.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner  index_column
# 0      Dealer       Manual      0             0
# ...

# %%
df.shape # (filas, columnas)
# Out:
# (301, 9)

# %%
#tamaño que ocupa en memoria
df.memory_usage(deep=True)
# Out:
# Index              128
# Car_Name         20124
# Year              2408
# Selling_Price     2408
# Present_Price     2408
# Kms_Driven        2408
# Fuel_Type        18957
# Seller_Type      19387
# Transmission     19083
# Owner             2408
# dtype: int64

# %%
# verificar si hay datos faltantes
df.isnull().sum() # no hay datos faltantes
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['index_column'] = df.index
dispersion_precie= df.plot.scatter(x="index_column",y="Present_Price")

# %%
df['index_column'] = df.index
dispersion_precie= df.plot.scatter(x="index_column",y="Kms_Driven")

# %%
df['index_column'] = df.index
dispersion_precie= df.plot.scatter(x="index_column",y="Selling_Price")

# %%
sns.boxplot(x=df['Year'],y=df['Present_Price'], data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Present_Price'>

# %%
sns.boxplot(x=df['Year'],y=df['Kms_Driven'], data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Kms_Driven'>

# %%
sns.boxplot(x=df['Year'],y=df['Selling_Price'], data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Selling_Price'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Realizar un análisis preliminar
#
# ### ¿Cuál es la dimensión del conjunto de datos?
# - La dimension es de (301 columnas, 9 filas)
#
# ### ¿Cuál es el tamaño que ocupa en memoria?
# - Tiene un tamaño en memoria de 2408 Bytes
#
# ### ¿Existen datos faltantes? Si es así debe tratarlos
# - No existe datos faltantes

# %% [markdown]
# # Realice un resumen estadístico de los datos
#
# ### ¿ Es posible observar outliers? Utilice gráficos
# - Realizando el grafico boxplot se puede ver que  los  valores atípicos
#
# ### ¿ Cuáles son las dos variables que presentan mayor dispersión?
# - Se puede ver que las variables con mayor dispersión son Kms_Driven y Present_Price
#
# ### ¿ Cuál es la correlación entre las variables?
#
# - Analizando el grafico heatmap puedo deducir que la variable Present_Price con Selling_Price es positiva y Kms_Driven con Year es negativa
#
# ### Elija una variable con la que puede calcular una predicción (variable dependiente), luego cite las variables independientes que tienen una fuerte correlación con la variable dependiente
#
# - La variable Year seria la variable independiete
# - La variable Kms_Drive seria la variable dependiente
